# %%
from wrapper_functions import sgp4_wrapper

# %%
filename = 'test_tles.txt'
output = sgp4_wrapper(filename)

# %%
import numpy as np
from stk_validation import load_stk_ephemeris
filename = '/Users/dyhdaas1/Projects/python_SGP4/Validation/ISS/ISS_25544_Fixed.e'

stk_data = load_stk_ephemeris(filename)

# %%
from helper_functions import make_difference_plot

# %%
make_difference_plot(stk_data, output[0])
